# %%
import pandas as pd
import numpy as np

# %%
test= pd.read_csv('E:/University of Bremen MSc/masters_thesis/IAT_sebastian/dataset_15_april_10000_1.csv')

# %%
test.info()

# %%
# extract1_1=test.loc[:10,['longTime','AEOETZKK1_V0', 'AEKGTZKK1_V0', 'AEHGTZKK1_V0','RWQBTZKK1_Q0','AEDATZKE1_V0'
#                         ,'AEOETZKK2_V0', 'AEEGTZKK2_V0', 'AEKGTZKK2_V0', 'AEHGTZKK2_V0','RWQBTZKK2_Q0', 'AEDATZKE2_V0',
#                         'AEOETZKK2_V0','AEEGTZKK2_V0','AEKGTZKK2_V0','AEHGTZKK2_V0','RWQBTZKK2_Q0','AEDATZKE2_V0',
#                         'AEDATZ_HONP0','AEDATZK_ASP0']]
# print(extract1_1)

# %%
import time
import datetime

longTime=test.loc[5000:5060:1,['longTime']]
longTime=longTime.as_matrix()
# print(type(longTime))
a=[]
date_time_array=[]
for k in longTime:
    a=np.append(a,k)

# print(a[0:])
# print(a[-2:])
count=0
for b in a[::-1]:
    b=int(b) # make plain integer
    str_b=str(b)
    c=str_b[-3:]
    new_str_b=str_b.replace(c, '',1)
    new_str_b_time=int(new_str_b)
    
    now_time=datetime.datetime.fromtimestamp(new_str_b_time)
    convert_time=now_time.strftime('%Y-%m-%d %H:%M:%S')
    
#     print('count_num: ',count,' unix_time: ',convert_time)
    date_time_obj = datetime.datetime.strptime(convert_time, '%Y-%m-%d %H:%M:%S')
    date_time_array=np.append(date_time_array,date_time_obj)
#     print('count_num: ',count,' convert_time: ',convert_time," date_time_obj: ",date_time_obj," str_time",new_str_b_time)
#     count+=1

# print(date_time_array.size)
for q in date_time_array[::1]:
# #     q=q.split(" ")
# #     split_q=np.append(split_q,q)
    print("count: ",count," date: ",q.date()," time: ",q.time())
    count+=1
# #     print(type(q))
# Out:
# count:  0  date:  2019-04-07  time:  08:40:00
# count:  1  date:  2019-04-07  time:  08:41:00
# count:  2  date:  2019-04-07  time:  08:42:00
# count:  3  date:  2019-04-07  time:  08:43:00
# count:  4  date:  2019-04-07  time:  08:44:00
# count:  5  date:  2019-04-07  time:  08:45:00
# count:  6  date:  2019-04-07  time:  08:46:00
# count:  7  date:  2019-04-07  time:  08:47:00
# count:  8  date:  2019-04-07  time:  08:48:00
# count:  9  date:  2019-04-07  time:  08:49:00
# count:  10  date:  2019-04-07  time:  08:50:00
# count:  11  date:  2019-04-07  time:  08:51:00
# count:  12  date:  2019-04-07  time:  08:52:00
# count:  13  date:  2019-04-07  time:  08:53:00
# count:  14  date:  2019-04-07  time:  08:54:00
# count:  15  date:  2019-04-07  time:  08:55:00
# count:  16  date:  2019-04-07  time:  08:56:00
# count:  17  date:  2019-04-07  time:  08:57:00
# count:  18  date:  2019-04-07  time:  08:58:00
# count:  19  date:  2019-04-07  time:  08:59:00
# count:  20  date:  2019-04-07  time:  09:00:00
# count:  21  date:  2019-04-07  time:  09:01:00
# count:  22  date:  2019-04-07  time:  09:02:00
# count:  23  date:  2019-04-07  time:  09:03:00
# count:  24  date:  2019-04-07  time:  09:04:00
# count:  25  date:  2019-04-07  time:  09:05:00
# count:  26  date:  2019-04-07  time:  09:06:00
# count:  27  date:  2019-04-07  time:  09:07:00
# count:  28  date:  2019-04-07  time:  09:08:00
# count:  29  date:  2019-04-07  time:  09:09:00
# count:  30  date:  2019-04-07  time:  09:10:00
# count:  31  date:  2019-04-07  time:  09:11:00
# count:  32  date:  2019-04-07  time:  09:12:00
# count:  33  date:  2019-04-07  time:  09:13:00
# count:  34  date:  2019-04-07  time:  09:14:00
# count:  35  date:  2019-04-07  time:  09:15:00
# count:  36  date:  2019-04-07  time:  09:16:00
# count:  37  date:  2019-04-07  time:  09:17:00
# count:  38  date:  2019-04-07  time:  09:18:00
# count:  39  date:  2019-04-07  time:  09:19:00
# count:  40  date:  2019-04-07  time:  09:20:00
# count:  41  date:  2019-04-07  time:  09:21:00
# count:  42  date:  2019-04-07  time:  09:22:00
# count:  43  date:  2019-04-07  time:  09:23:00
# count:  44  date:  2019-04-07  time:  09:24:00
# count:  45  date:  2019-04-07  time:  09:25:00
# count:  46  date:  2019-04-07  time:  09:26:00
# count:  47  date:  2019-04-07  time:  09:27:00
# count:  48  date:  2019-04-07  time:  09:28:00
# count:  49  date:  2019-04-07  time:  09:29:00
# count:  50  date:  2019-04-07  time:  09:30:00
# count:  51  date:  2019-04-07  time:  09:31:00
# count:  52  date:  2019-04-07  time:  09:32:00
# count:  53  date:  2019-04-07  time:  09:33:00
# count:  54  date:  2019-04-07  time:  09:34:00
# count:  55  date:  2019-04-07  time:  09:35:00
# count:  56  date:  2019-04-07  time:  09:36:00
# count:  57  date:  2019-04-07  time:  09:37:00
# count:  58  date:  2019-04-07  time:  09:38:00
# count:  59  date:  2019-04-07  time:  09:39:00
# count:  60  date:  2019-04-07  time:  09:40:00
# C:\Users\atif\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """

# %%
# import datetime
# import matplotlib.pyplot as plt
# import matplotlib.dates as md
# import numpy as np
# import datetime as dt
# import time
# %matplotlib inline

# start_index=650
# end_index=800
# interval_index=1#place it after end_index. start_index:end_index:interval_index
# minute_interval=10

# longTime=test.loc[start_index:end_index:interval_index,['longTime']]
# longTime=longTime.as_matrix()
# print(longTime.size)
# a=[]
# date_time_array=[]
# for k in longTime:
#     a=np.append(a,k)

# timestamp_array=[]
# count=0
# for b in a[::-1]:
#     b=int(b) # make plain integer
#     str_b=str(b)
#     c=str_b[-3:]
#     new_str_b=str_b.replace(c, '',1)
#     new_str_b_time=int(new_str_b)
#     timestamp_array=np.append(timestamp_array,new_str_b_time)
# # print(timestamp_array[::5])
# duration=1000
# # timestamp_arrays=[]
# # timestamp_arrays=np.linspace(timestamp_array[0],timestamp_array[0]+duration,len(timestamp_array))
# # print(timestamp_arrays)
# # print(np.linspace(timestamp_array[0],timestamp_array[0]+duration,len(timestamp_array)))

# date_list=[dt.datetime.fromtimestamp(ts) for ts in timestamp_array]
# # for r in date_list:
# #     print(r)
# # print(date_list[::5])

# datenums_array=md.date2num(date_list)
# # for w in datenums_array:
# #     print(w)
# # print(type(datenums_array))

# value_1=test.loc[start_index:end_index:interval_index,['RWWIHOA_MWT0','AEDAT_3_80V0']]
# value_1=value_1.as_matrix()

# RWWIHOA_MWT0=value_1[::,0]
# RWWIHOA_MWT0=RWWIHOA_MWT0[::-1]

# AEDAT_3_80V0=value_1[::,1]
# AEDAT_3_80V0=AEDAT_3_80V0[::-1]

# print(max(RWWIHOA_MWT0),'\n',min(RWWIHOA_MWT0))
# print(max(AEDAT_3_80V0),'\n',min(AEDAT_3_80V0))

# plt.title('graph')
# plt.subplots_adjust(bottom=.2)
# plt.xticks( rotation=25)
# ax=plt.gca()

# minlocator = md.MinuteLocator(interval=minute_interval) # to plot every minute of an range
# # minlocator.MAXTICKS  = 40000
# ax.xaxis.set_major_locator(minlocator)

# xfmt = md.DateFormatter('%Y-%m-%d %H:%M:%S')
# ax.xaxis.set_major_formatter(xfmt)
# # plt.subplot(2,1,1)
# plt.plot(datenums_array,RWWIHOA_MWT0,color='orange') #you can give here datenums_array
# plt.plot(datenums_array,AEDAT_3_80V0,color='RED')
# # plt.plot(datenums_array,value_1,color='red')
# plt.gcf().autofmt_xdate() # to beautify the X label
# # plt.title('2nd graph')
# # plt.subplot(1,2,2) #1 row, 2 cols, position
# # plt.xlabel('date_time')
# # plt.ylabel('value_1_rev')
# # plt.plot(datenums_array,value_1)
# # plt.xlim((min(datenums_array),max(datenums_array)))
# plt.xlim(datenums_array[0],datenums_array[-1])
# # plt.ylim(40,60)
# # print(min(datenums_array),max(datenums_array))
# # print(datenums_array[0],datenums_array[-1])
# plt.show()

# %%
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as md
import numpy as np
import datetime as dt
import time
# %matplotlib inline

start_index=650
end_index=800
interval_index=1#place it after end_index. start_index:end_index:interval_index
minute_interval=10

longTime=test.loc[start_index:end_index:interval_index,['longTime']]
longTime=longTime.as_matrix()
print(longTime.size)
a=[]
date_time_array=[]
for k in longTime:
    a=np.append(a,k)

timestamp_array=[]
count=0
for b in a[::-1]:
    b=int(b) # make plain integer
    str_b=str(b)
    c=str_b[-3:]
    new_str_b=str_b.replace(c, '',1)
    new_str_b_time=int(new_str_b)
    timestamp_array=np.append(timestamp_array,new_str_b_time)
# print(timestamp_array[::5])
duration=1000
# timestamp_arrays=[]
# timestamp_arrays=np.linspace(timestamp_array[0],timestamp_array[0]+duration,len(timestamp_array))
# print(timestamp_arrays)
# print(np.linspace(timestamp_array[0],timestamp_array[0]+duration,len(timestamp_array)))

date_list=[dt.datetime.fromtimestamp(ts) for ts in timestamp_array]
# for r in date_list:
#     print(r)
# print(date_list[::5])

datenums_array=md.date2num(date_list)
# for w in datenums_array:
#     print(w)
# print(type(datenums_array))

value_1=test.loc[start_index:end_index:interval_index,['RWWIHOA_MWT0','AEDAT_3_80V0']]
value_1=value_1.as_matrix()

RWWIHOA_MWT0=value_1[::,0]
RWWIHOA_MWT0=RWWIHOA_MWT0[::-1]

AEDAT_3_80V0=value_1[::,1]
AEDAT_3_80V0=AEDAT_3_80V0[::-1]

print(max(RWWIHOA_MWT0),'\n',min(RWWIHOA_MWT0))
print(max(AEDAT_3_80V0),'\n',min(AEDAT_3_80V0))

plt.title('graph')
plt.subplots_adjust(bottom=.2)
plt.xticks( rotation=25)
ax=plt.gca()

minlocator = md.MinuteLocator(interval=minute_interval) # to plot every minute of an range
# minlocator.MAXTICKS  = 40000
ax.xaxis.set_major_locator(minlocator)

xfmt = md.DateFormatter('%Y-%m-%d %H:%M:%S')
ax.xaxis.set_major_formatter(xfmt)


# plt.subplot(211)
plt.plot(datenums_array,RWWIHOA_MWT0,color='orange') #you can give here datenums_array
plt.title('Story of Power Plant')
plt.ylabel('RWWIHOA_MWT0')
plt.xlabel('Time')

# plt.subplot(212)
# plt.plot(datenums_array,AEDAT_3_80V0,color='RED')
# plt.xlabel('Time')
# plt.ylabel('AEDAT_3_80V0')
plt.gcf().autofmt_xdate() # to beautify the X label
# plt.xlim((min(datenums_array),max(datenums_array)))
plt.xlim(datenums_array[0],datenums_array[-1])
# plt.ylim(40,60)
# plt.subplots_adjust(hspace=1.4, wspace=1.4)
# plt.tight_layout() #to remove overlapping among of subplot
plt.show()

# %%
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as md
import numpy as np
import datetime as dt
import time
# %matplotlib inline
start_index=5000
end_index=start_index+60
interval_index=1#place it after end_index. start_index:end_index:interval_index
minute_interval=5

def time_graph(y_item):
    global start_index
    global end_index
    global interval_index
#     global minute_interval
    
    longTime=test.loc[start_index:end_index:interval_index,['longTime']]
    longTime=longTime.as_matrix()
    print(longTime.size)
    a=[]
    date_time_array=[]
    for k in longTime:
        a=np.append(a,k)

    timestamp_array=[]
    count=0
    for b in a[::-1]:
        b=int(b) # make plain integer
        str_b=str(b)
        c=str_b[-3:]
        new_str_b=str_b.replace(c, '',1)
        new_str_b_time=int(new_str_b)
        timestamp_array=np.append(timestamp_array,new_str_b_time)
# print(timestamp_array[::5])
#     duration=1000
# timestamp_arrays=[]
# timestamp_arrays=np.linspace(timestamp_array[0],timestamp_array[0]+duration,len(timestamp_array))
# print(timestamp_arrays)
# print(np.linspace(timestamp_array[0],timestamp_array[0]+duration,len(timestamp_array)))

    date_list=[dt.datetime.fromtimestamp(ts) for ts in timestamp_array]
# for r in date_list:
#     print(r)
# print(date_list[::5])

    datenums_array=md.date2num(date_list)
    
    value_1=test.loc[start_index:end_index:interval_index,[y_item]]
    value_1=value_1.as_matrix()
    value_y=value_1[::,0]
    value_y=value_y[::-1]
    
    plt.title('graph')
    plt.subplots_adjust(bottom=.2)
    plt.xticks( rotation=25)
    ax=plt.gca()
    
    minlocator = md.MinuteLocator(interval=minute_interval) # to plot every minute of an range
#     minlocator.MAXTICKS  = 40000
    ax.xaxis.set_major_locator(minlocator)
    
    xfmt = md.DateFormatter('%Y-%m-%d %H:%M:%S')
    ax.xaxis.set_major_formatter(xfmt)
    plt.plot(datenums_array,value_y,color='orange') #you can give here datenums_array
    plt.title('Story of Power Plant')
    plt.ylabel(y_item)
    plt.xlabel('Time')
    plt.gcf().autofmt_xdate() # to beautify the X label
# plt.xlim((min(datenums_array),max(datenums_array)))
    plt.xlim(datenums_array[0],datenums_array[-1])
#     plt.ylim(40,60)
# plt.subplots_adjust(hspace=1.4, wspace=1.4)
    plt.tight_layout() #to remove overlapping among of subplot
    plt.show()


time_graph(y_item='RWWIHOA_MWT0')
time_graph(y_item='AEDAT_3_80V0')
time_graph(y_item='AEKGTZKK1_V0')
# Out:
# 61
# C:\Users\atif\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\atif\Anaconda3\lib\site-packages\ipykernel_launcher.py:51: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# 61
# 61
