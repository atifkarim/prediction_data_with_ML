# %%
import pandas as pd
import numpy as np

# %%
# test= pd.read_csv('E:/University of Bremen MSc/masters_thesis/IAT_sebastian/dataset_10_april_10000.csv')
test= pd.read_csv('E:/University of Bremen MSc/masters_thesis/IAT_sebastian/IAT_csv_10000.csv')
# test=pd.read_csv('/home/atif/IAT_new_dataset_10000.csv')

# %%
#For finding is there any column has empty value or not
null_columns=test.columns[test.isnull().any()]
test[null_columns].isnull().sum()

# %%
# print(test[test["RWQBTZKK1_Q0"].isnull()][null_columns])

# %%
test.loc[:]

# %%
# a=test.loc[0:10]
# print(type(a))
# # var=['longTime','AEOETZKK1_V0'] #acceptaböe
# extract1_1=a[['longTime','AEOETZKK1_V0']]
# print(type(extract1_1))

test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 4191 entries, row ID to RWWIHOSUMAV0
# dtypes: float64(4189), int64(1), object(1)
# memory usage: 1.6+ GB

# %%
# code for blast furnace temparature
#fig 2, signal 19
import matplotlib.pyplot as plt
# %matplotlib inline
time_t=test.loc[10:20,['longTime']]
blast_furnace_temp=test.loc[10:20,['RWWIHOA_MWT0']]
time_t=time_t.as_matrix()
blast_furnace_temp=blast_furnace_temp.as_matrix()

plt.title('blast_furnace_Temparature')
# plt.subplot(4, 1, 1) #1 row, 2 cols, position
plt.plot(time_t,blast_furnace_temp,color='red')
plt.xlabel('Time')
plt.ylabel('Temparature')
# Out:
# C:\Users\atif\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   import sys
# C:\Users\atif\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Text(0,0.5,'Temparature')

# %%
import dateparser
def parser(x):
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

data=pd.read_csv('/media/atif/BE0E05910E0543BD/University of Bremen MSc/masters_thesis/IAT_sebastian/IAT_csv_10000.csv',index_col=0,parser_dates=[0],date_parser=parser)

# %% [markdown]
# # Extracted data of 1st section of figure

# %%
#1st figure
#from 1 to 4
extract1_1=test.loc[:10,['longTime','AEOETZKK1_V0', 'AEKGTZKK1_V0', 'AEHGTZKK1_V0','RWQBTZKK1_Q0','AEDATZKE1_V0'
                        ,'AEOETZKK2_V0', 'AEEGTZKK2_V0', 'AEKGTZKK2_V0', 'AEHGTZKK2_V0','RWQBTZKK2_Q0', 'AEDATZKE2_V0',
                        'AEOETZKK2_V0','AEEGTZKK2_V0','AEKGTZKK2_V0','AEHGTZKK2_V0','RWQBTZKK2_Q0','AEDATZKE2_V0',
                        'AEDATZ_HONP0','AEDATZK_ASP0']]
print(extract1_1)
# Out:
#          longTime  AEOETZKK1_V0  AEKGTZKK1_V0  AEHGTZKK1_V0  RWQBTZKK1_Q0  \
# 0   1551465000000           0.0     98.568747     95.580754           NaN
# 1   1551464940000           0.0     99.109770     95.528469           NaN
# 2   1551464880000           0.0     99.559451     97.292486           NaN
# 3   1551464820000           0.0    100.000000     97.585958           NaN
# 4   1551464760000           0.0     98.938333     94.650342           NaN
# 5   1551464700000           0.0     98.470379     95.363258           NaN
# 6   1551464640000           0.0     97.412226     98.419562           NaN
# 7   1551464580000           0.0     97.819749     96.679027           NaN
# 8   1551464520000           0.0     98.150684     98.401179           NaN
# 9   1551464460000           0.0     98.506217     96.285907           NaN
# 10  1551464400000           0.0     99.034594     97.987034           NaN
#
#     AEDATZKE1_V0  AEOETZKK2_V0  AEEGTZKK2_V0  AEKGTZKK2_V0  AEHGTZKK2_V0  \
# ...

# %%
#1st figure
#from 5 to 12
extract1_2=test.loc[:10,['AEDABL1R80V0','AEDABL1 _40V0','AEDABL1S40V0','AEDABL2R80V0','AEDABL2 _40V0','AEDABL2S40V0','AEDABL0_20V0'
                        ,'RWDATZKREDV8','RWDAR80_8_V0','AEDAT_1_80V0','AEELMA1___E0','AEDAT_2_80V0','AEELMA2___E0','AEDAT_2_40V0',
                         'AEDAT_2_20V0','AEDAT_2__8V0','AEKDT_2___V0','AEDAT_3_80V0','AEELMA3___E0']]
print(extract1_2)
# Out:
#     AEDABL1R80V0  AEDABL1 _40V0  AEDABL1S40V0  AEDABL2R80V0  AEDABL2 _40V0  \
# 0   7.440753e-44            NaN      0.000081           0.0            NaN
# 1   7.440753e-44            NaN      0.000214           0.0            NaN
# 2   7.440753e-44            NaN      0.000224           0.0            NaN
# 3   7.440753e-44            NaN      0.000117           0.0            NaN
# 4   7.440753e-44            NaN      0.000291           0.0            NaN
# 5   7.440753e-44            NaN      0.000203           0.0            NaN
# 6   7.440753e-44            NaN      0.000118           0.0            NaN
# 7   7.440753e-44            NaN      0.000126           0.0            NaN
# 8   7.440753e-44            NaN      0.000229           0.0            NaN
# 9   7.440753e-44            NaN      0.000089           0.0            NaN
# 10  7.440753e-44            NaN      0.000141           0.0            NaN
#
# ...

# %%
#1st figure
#from 13 to 20
extract1_3=test.loc[:10,['AEDAT_A_80V0','AEELMAA___E0','AEDAT_A_80V0','AEDATZ_HO_V0','RWDAKRWRS8V0',
                        'AEDAHO_T8_V2','AEWIHO_T8AV2','AEDAHO_T9_V2','AEWIHO_T9AV2','AEDATZ_TZCP2',
                        'AEDATZKA_8P0','AEDATZ_HO_P1','RWKGTZKK3_Q0']]
print(extract1_3)
#last one sebastian has given

# %% [markdown]
# # Extracted data of 2nd section of figure

# %%
#2nd figure
#from 1 to 3
extract2_1=test.loc[:10,['longTime','AEWIHOAVAB2','RWWIHOAK__V0', 'AEWIHOAK__P0', 
                         'AEWIHOAK__T0', 'AEWIHOAWF_A2', 'RWWIHOAWF_A0','AEDAHOAWF_V0']]
print(extract2_1)

# %%
#2nd figure
#from 4 to 19
extract2_2=test.loc[:10,['AEO2HOA___V0','AEAGHOAWE1T0', 'AEAGHOAWE1T1','AEAGHOAWE2T0','AEAGHOAWE2T1','AEAGHOAWE3T0', 
                         'AEAGHOAWE3T1','AEMGHOAWE1V0','AELUHOAWE1V0','AEAGHOAWE1A0','AEMGHOAWE2V0','AELUHOAWE2V0','AEAGHOAWE2A0',
                         'AEMGHOAWE3V0','AELUHOAWE3V0','AEAGHOAWE3A0','RWWIHOA_HWT0','AEWIHOAKZ_V0','RWWIHOA_MWT0', 'RWWIHOAM__P0']]
print(extract2_2)

# %% [markdown]
# # Extracted data of 3rd section of figure

# %%
#3rd figure
#from 1 to 7
extract3_1=test.loc[:10,['AECOHOA___V0','AEOSHOA___V0','RWWIHOAK__V0','RWHGHOAHU_A0','RWHGHOAKHUA0','RWHGHOACO2A0','RWHGHOAH2_A0',
                         'RWHGHOACO_A0','RWHGHOAERZV0','AEHGHOA___T0','AEHGHOAKOPP0','AEHGHOASOKG0','AEHGHOABRKG0','RWHGHOATURT0',
                         'RWHGHOATURP0','AEELHOATURE0','RWHGHOATURP1','RWHGHOATURT1','RWHGHOANETV0','AEHGHOAREIV1']]
print(extract3_1)

# %%
#3rd figure
#from 8 to 13
extract3_2=test.loc[:10,['AEHGHOA_MDP1','AEHGHOA_MDP1','AEHGK2_BS_G0','AEHGKWB__V1','AEHGK1___G0','AEHGNK1_NDP0',
                        'AEHGHOAWE_P1','AEHGHOAWE_V0','AEEGHOAWE_V0']]
print(extract3_2)

# %%
# extract1_1=test.loc[:500,['longTime','AEOETZKK1_V0','AEKGTZKK1_V0']]
# print(extract1_1)
var_1=extract1_1.as_matrix()
print(type(var_1))
print(var_1)

# %%
# print(var_1[:,8])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
time=var_1[:100,0]
var_2=var_1[:100,14]
norm_var_2=var_2/var_2.max(axis=0)
var_3=var_1[:100,2]
norm_var_3=var_3/var_3.max(axis=0)
# print(min(time))
# print(max(time))
plt.title('testing')
plt.subplot(4, 1, 1) #1 row, 2 cols, position
plt.plot(time,var_2,color='red')
plt.xlabel('Time')
plt.ylabel('output')

plt.subplot(4, 1, 2)
plt.plot(time,norm_var_2,color='orange')
# plt.plot(time,actual_op,color='orange')
plt.xlabel('Time')
plt.ylabel('output')

plt.subplot(4, 1,3)
plt.plot(time,var_3,color='yellow')
plt.xlabel('Time')
plt.ylabel('output')

plt.subplot(4, 1,4)
plt.plot(time,var_3,color='pink')
plt.xlabel('Time')
plt.ylabel('output')

# plt.xticks(np.arange(min(time), max(time), 5000))
plt.show()

# %%
var_2=var_1[:100,14]
print(var_2)
norm_var_2=var_2/var_2.max(axis=0)
print(norm_var_2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

x = [0,5,9,10,15]
y = [0,1,2,3,4]
fig, ax = plt.subplots()
ax.plot(x,y)
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, 0.712123))
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%0.1f'))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = [0,5,9,10,15]
y = [0,1,2,3,4]
plt.plot(x,y)
plt.xticks(np.arange(min(x), max(x)+5, 100000000))
plt.show()

# %%
import matplotlib.pyplot as plt
f1 = plt.figure()
f2 = plt.figure()
ax1 = f1.add_subplot(111)
ax1.plot(range(0,10))
ax2 = f2.add_subplot(111)
ax2.plot(range(10,20))
plt.show()

# %%
extract_missing=test.loc[:10,['longTime','RWQBTZKK1_Q0','RWQBTZKK2_Q0', 'RWQBTZKK2_Q0', 
                         'AEDABL1 _40V0', 'AEDABL2 _40V0', 'RWDATZKREDV8','RWDAR80_8_V0','RWDAKRWRS8V0','AEWIHOAVAB2','RWHGHOATURT1',
                             'RWHGHOANETV0','AEHGKWB__V1','AEHGK1___G0']]
print(extract_missing)

# %%
ex=test.loc[:,['RWDATZKREDV8','RWQBTZKK1_Q0','AEDAR_1___V0','AEDAR_1A__V0','AEDAR_2___V0','AEDAR_2A__V0','AADATZKDIFV0']]
print(ex)

# %%
import csv
filename1='E:/University of Bremen MSc/masters_thesis/IAT_sebastian/dataset_10_april_10000.csv'
with open(filename1, 'r') as f1:
    csvlines = csv.reader(f1, delimiter=',')

for lineNum, line in enumerate(csvlines):
    if lineNum == 0:
        colCount = getColCount(line)
        headings = ','.join(line)           # gives me  `love, hurt, hit`
        print (len(line))                 # gives me 14; I need 
    else:
        pass
#            a.append(line[0])
#            b.append(line[1])
#            c.append(line[2])

# %%
import numpy as np
X=['atif','bin','Karim','raif']
X=np.array(X)
for i in X:
    i=i.split('')
    print(i)
# Y=[]
# Y=np.array(Y)
# print('here Y is: ',Y)
# X=np.array(X)
# print(X)
# for i in X:
# #     print('ok')
#     if (i[-1]=='f') and (i[-2]=='i'):
#         if 1<2:
#             print(i)
#             Y=np.append(Y,i)
# print('Y: ',Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-8c0423887491> in <module>()
#       3 X=np.array(X)
#       4 for i in X:
# ----> 5     i=i.split('')
#       6     print(i)
#       7 # Y=[]
#
# ValueError: empty separator

# %%
#work with longtime
import time
import datetime

longTime=test.loc[0:1000,['longTime']]
longTime=longTime.as_matrix()
# print(type(longTime))
a=[]
time_array=[]
for k in longTime:
    a=np.append(a,k) #here directly value from csv inserted to array a

# print(a.size)
count=0
for b in a[::-1]:
    b=int(b) # make plain integer
    str_b=str(b) #make string
    c=str_b[-3:] #taking last 3 charecter of each string to replace
    new_str_b=str_b.replace(c, '',1) # here make new string where last 3 charecter is removed
    new_str_b_time=int(new_str_b)
    
#     print("hi:",b,"\nHi:",new_str_b_time)
    
    now_time=datetime.datetime.fromtimestamp(new_str_b_time)
    convert_time=now_time.strftime('%Y-%m-%d %H:%M:%S')
    print('count:',count,' str:',new_str_b_time,'unix_time:',convert_time)
    count+=1
    time_array=np.append(time_array,convert_time)
# print(time_array)
split_q=[]
for q in time_array:
    q=q.split(" ")
#     split_q=np.append(split_q,q)
#     print((q[1]))
    1==2
#     print(type(q))
# Out:
# C:\Users\atif\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# count: 0  str: 1550819940 unix_time: 2019-02-22 08:19:00
# count: 1  str: 1550820000 unix_time: 2019-02-22 08:20:00
# count: 2  str: 1550820060 unix_time: 2019-02-22 08:21:00
# count: 3  str: 1550820120 unix_time: 2019-02-22 08:22:00
# count: 4  str: 1550820180 unix_time: 2019-02-22 08:23:00
# count: 5  str: 1550820240 unix_time: 2019-02-22 08:24:00
# count: 6  str: 1550820300 unix_time: 2019-02-22 08:25:00
# count: 7  str: 1550820360 unix_time: 2019-02-22 08:26:00
# count: 8  str: 1550820420 unix_time: 2019-02-22 08:27:00
# count: 9  str: 1550820480 unix_time: 2019-02-22 08:28:00
# count: 10  str: 1550820540 unix_time: 2019-02-22 08:29:00
# count: 11  str: 1550820600 unix_time: 2019-02-22 08:30:00
# count: 12  str: 1550820660 unix_time: 2019-02-22 08:31:00
# count: 13  str: 1550820720 unix_time: 2019-02-22 08:32:00
# ...

# %%
import time
import datetime
dateTime = datetime.date(2015,1,5)
unixtime = time.mktime(dateTime.timetuple())
print(unixtime)
# Out:
# 1420412400.0

# %%
import datetime
date = datetime.datetime.fromtimestamp(1954998900)
hi=date.strftime('%Y-%m-%d %H:%M:%S')
print(hi)
# Out:
# 2031-12-14 08:15:00

# %%
print(time_t.ndim)
a=[]
for w in time_t:
    a=np.append(a,w)
    
print(type(a))
print(a.ndim)
# Out:
# 2
# <class 'numpy.ndarray'>
# 1

# %%
s = 'ab12abc34ba'
print(s.replace('ab', '',0))
# Out:
# ab12abc34ba

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as md
import numpy as np
import datetime as dt
import time
# %matplotlib inline

n=20
duration=1000
now=time.mktime(time.localtime())
timestamps=np.linspace(now,now+duration,n)
dates=[dt.datetime.fromtimestamp(ts) for ts in timestamps]
print(type(dates[0]))
datenums=md.date2num(dates)
values=np.sin((timestamps-now)/duration*2*np.pi)
plt.subplots_adjust(bottom=0.2)
plt.xticks( rotation=25)
ax=plt.gca()
xfmt = md.DateFormatter('%Y-%m-%d %H:%M:%S')
print(type(xfmt))
ax.xaxis.set_major_formatter(xfmt)
plt.plot(datenums,values)
plt.show()
# Out:
# <class 'datetime.datetime'>
# <class 'matplotlib.dates.DateFormatter'>
